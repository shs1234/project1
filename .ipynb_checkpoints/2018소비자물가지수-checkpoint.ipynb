# %%
import pandas as pd

# %%
df = pd.read_csv('C:/project1/data/2018소비자물가지수.csv', encoding='cp949', header=None)
df
# Out:
#      0                    1         2         3         4         5   \
# 0   시도별                지출목적별  2018. 01  2018. 02  2018. 03  2018. 04
# 1    전국                0 총지수    103.42    104.21    104.10    104.29
# 2    전국       01 식료품 · 비주류음료    106.00    109.07    107.32    107.86
# 3    전국           02 주류 및 담배    102.48    102.58    102.39    102.52
# 4    전국           03 의류 및 신발    103.34    103.96    104.05    104.06
# 5    전국  04 주택 ·수도 · 전기 및 연료    101.06    101.63    101.80    101.78
# 6    전국     05 가정용품 및 가사 서비스    103.50    104.33    105.08    104.60
# 7    전국                06 보건    102.51    102.55    102.65    102.21
# 8    전국                07 교통    102.80    103.07    103.00    102.72
# 9    전국                08 통신     99.89     99.76     99.67    100.15
# 10   전국           09 오락 및 문화    100.45    101.87    101.56    103.14
# 11   전국                10 교육    103.40    103.69    103.99    104.20
# 12   전국           11 음식 및 숙박    106.55    106.94    107.29    107.70
# ...

# %%
df = pd.read_csv('C:/project1/data/2018소비자물가지수.csv', encoding='cp949', header=0).iloc[:, 2:]
df1 = pd.DataFrame(df.T[0])
df1
# Out:
#                0
# 2018. 01  103.42
# 2018. 02  104.21
# 2018. 03  104.10
# 2018. 04  104.29
# 2018. 05  104.34
# 2018. 06  104.13
# 2018. 07  103.93
# 2018. 08  104.85
# 2018. 09  105.65
# 2018. 10  105.46
# 2018. 11  104.71
# 2018. 12  104.35

# %%
df1.index.dtype
# Out:
# dtype('O')
